# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
#df = pd.read_csv("C:\Users\breno\GitHub\PI\codigos_python/datasus.csv")

#df = pd.read_csv("datasus.csv")
#C:\Users\breno\anaconda3\envs\envpowerbi\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (4,30,31,32,42,43,52,59,60,78,79,81,82,83,85,89,91,93) have mixed types.Specify dtype option on import or set low_memory=False.
#  interactivity=interactivity, compiler=compiler, result=result)

df = pd.read_csv("datasus.csv", low_memory=False)

# %%
# Carregando os dados
data = pd.read_csv("datasus.csv", low_memory=False)

# Visualizando as primeiras linhas do DataFrame
print(data.head())
# Out:
#    CONTADOR  ORIGEM   TIPOBITO     DTOBITO HORAOBITO NATURAL      DTNASC  \
# 0         1       1  Não Fetal  2010-07-22      0700     NaN  1933-01-18
# 1         2       1  Não Fetal  2010-08-30      0700     NaN  1945-11-05
# 2         3       1  Não Fetal  2010-09-25      1700     NaN  1938-05-26
# 3         4       1  Não Fetal  2010-01-29      0740     NaN  1966-03-04
# 4         5       1  Não Fetal  2010-07-01      1600     NaN  1927-11-04
#
#         SEXO  RACACOR    ESTCIV  ... TPRESGINFO TPNIVELINV  NUDIASINF  \
# 0  Masculino   Branca    Casado  ...        NaN        NaN        NaN
# 1   Feminino    Preta  Solteiro  ...        NaN        NaN        NaN
# 2  Masculino  Amarela    Casado  ...        NaN        NaN        NaN
# 3  Masculino      NaN  Solteiro  ...        NaN        NaN        NaN
# 4  Masculino   Branca     Viúvo  ...        NaN        NaN        NaN
#
#    FONTESINF ALTCAUSA  IDADEminutos  IDADEhoras  IDADEdias  IDADEmeses  \
# 0        NaN      NaN           NaN         NaN        NaN         NaN
# 1        NaN      NaN           NaN         NaN        NaN         NaN
# 2        NaN      NaN           NaN         NaN        NaN         NaN
# 3        NaN      NaN           NaN         NaN        NaN         NaN
# 4        NaN      NaN           NaN         NaN        NaN         NaN
#
#   IDADEanos
# 0      77.0
# 1      64.0
# 2      72.0
# 3      43.0
# 4      82.0
#
# [5 rows x 100 columns]

# %%
# Configurações para visualização
sns.set(style="whitegrid")

# %%
# Configurar o Pandas para exibir todas as colunas
pd.set_option('display.max_columns', None)

# Imprimir a contagem de valores nulos para todas as colunas
print(data.isnull().sum())
# Out:
# CONTADOR              0
# ORIGEM                0
# TIPOBITO              0
# DTOBITO               0
# HORAOBITO        193434
#                  ...
# IDADEminutos    3977796
# IDADEhoras      3970398
# IDADEdias       3940634
# IDADEmeses      3957382
# IDADEanos         94396
# Length: 100, dtype: int64

# %%
# Verificando a distribuição de algumas variáveis categóricas
plt.figure(figsize=(10, 6))
sns.countplot(x='SEXO', data=data)
plt.title('Distribuição por Sexo')
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(x='RACACOR', data=data)
plt.title('Distribuição por Raça/Cor')
plt.show()

# Explorando um pouco mais a idade dos indivíduos
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='IDADEMAE', bins=30, kde=True)
plt.title('Distribuição da Idade da Mãe')
plt.xlabel('Idade')
plt.ylabel('Contagem')
plt.show()

# %%
# Verificando informações sobre os dados
print(data.info())

# Verificando valores ausentes
print(data.isnull().sum())

# Lidando com valores ausentes (preenchendo ou removendo)

# Removendo colunas irrelevantes
data = data.drop(columns=['CONTADOR', 'ORIGEM', 'DTOBITO', 'HORAOBITO', 'NATURAL', 'LOCOCOR', 'CODESTAB', 'CODMUNOCOR', 'CODBAIOCOR', 'ESCMAE', 'OCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'GRAVIDEZ', 'GESTACAO', 'PARTO', 'OBITOPARTO', 'PESO', 'OBITOGRAV', 'OBITOPUERP', 'ASSISTMED', 'EXAME', 'CIRURGIA', 'NECROPSIA', 'LINHAA', 'LINHAB', 'LINHAC', 'LINHAD', 'LINHAII', 'DTATESTADO', 'CIRCOBITO', 'ACIDTRAB', 'FONTE', 'TPPOS', 'DTINVESTIG', 'CAUSABAS_O', 'DTCADASTRO', 'ATESTANTE', 'FONTEINV', 'DTRECEBIM', 'UFINFORM', 'CB_PRE', 'MORTEPARTO', 'DTCADINF', 'TPOBITOCOR', 'DTCADINV', 'COMUNSVOIM', 'DTRECORIG', 'DTRECORIGA', 'CAUSAMAT', 'ESC2010', 'ESCMAE2010', 'STDOEPIDEM', 'STDONOVA', 'SEMAGESTAC', 'TPMORTEOCO', 'DIFDATA', 'DTCONCASO', 'NUDIASOBIN', 'SERIESCFAL', 'SERIESCMAE', 'CODMUNCART', 'CODCART', 'NUMREGCART', 'DTREGCART', 'DTCONINV', 'CODMUNNATU', 'ESTABDESCR', 'CRM', 'NUMEROLOTE', 'STCODIFICA', 'CODIFICADO', 'VERSAOSIST', 'VERSAOSCB', 'ATESTADO', 'ESCMAEAGR1', 'ESCFALAGR1', 'NUDIASOBCO', 'FONTES', 'TPRESGINFO', 'TPNIVELINV', 'NUDIASINF', 'FONTESINF', 'ALTCAUSA', 'IDADEminutos', 'IDADEhoras', 'IDADEdias', 'IDADEmeses', 'IDADEanos'])

# Convertendo a coluna 'DTOBITO' para datetime
data['DTOBITO'] = pd.to_datetime(data['DTOBITO'])

# Convertendo a coluna 'SEXO' para valores numéricos (0 para Feminino e 1 para Masculino)
data['SEXO'] = data['SEXO'].apply(lambda x: 0 if x == 'Feminino' else 1)

# Convertendo a coluna 'RACACOR' para valores numéricos usando LabelEncoder
label_encoder = LabelEncoder()
data['RACACOR'] = label_encoder.fit_transform(data['RACACOR'])

# Convertendo a coluna 'ESTCIV' para valores numéricos usando LabelEncoder
data['ESTCIV'] = label_encoder.fit_transform(data['ESTCIV'].astype(str))

# Convertendo a coluna 'ESC' para valores numéricos usando LabelEncoder
data['ESC'] = label_encoder.fit_transform(data['ESC'].astype(str))

# Convertendo a coluna 'OCUP' para valores numéricos usando LabelEncoder
data['OCUP'] = label_encoder.fit_transform(data['OCUP'].astype(str))

# Convertendo a coluna 'CODMUNRES' para valores numéricos usando LabelEncoder
data['CODMUNRES'] = label_encoder.fit_transform(data['CODMUNRES'])

# Convertendo a coluna 'CODBAIRES' para valores numéricos usando LabelEncoder
data['CODBAIRES'] = label_encoder.fit_transform(data['CODBAIRES'])

# Visualizando as primeiras linhas após a limpeza e pré-processamento
print(data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3982921 entries, 0 to 3982920
# Data columns (total 100 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   CONTADOR      int64
#  1   ORIGEM        int64
#  2   TIPOBITO      object
#  3   DTOBITO       object
#  4   HORAOBITO     object
#  5   NATURAL       object
#  6   DTNASC        object
#  7   SEXO          object
#  8   RACACOR       object
#  9   ESTCIV        object
#  10  ESC           object
#  11  OCUP          object
#  12  CODMUNRES     int64
#  13  CODBAIRES     float64
#  14  LOCOCOR       object
#  15  CODESTAB      float64
#  16  CODMUNOCOR    int64
#  17  CODBAIOCOR    float64
#  18  IDADEMAE      float64
#  19  ESCMAE        object
#  20  OCUPMAE       object
#  21  QTDFILVIVO    float64
#  22  QTDFILMORT    float64
#  23  GRAVIDEZ      object
#  24  GESTACAO      object
#  25  PARTO         object
#  26  OBITOPARTO    object
#  27  PESO          float64
#  28  OBITOGRAV     object
#  29  OBITOPUERP    object
#  30  ASSISTMED     object
#  31  EXAME         object
#  32  CIRURGIA      object
#  33  NECROPSIA     object
#  34  LINHAA        object
#  35  LINHAB        object
#  36  LINHAC        object
#  37  LINHAD        object
#  38  LINHAII       object
#  39  CAUSABAS      object
#  40  DTATESTADO    object
#  41  CIRCOBITO     object
#  42  ACIDTRAB      object
#  43  FONTE         object
#  44  TPPOS         object
#  45  DTINVESTIG    object
#  46  CAUSABAS_O    object
#  47  DTCADASTRO    object
#  48  ATESTANTE     object
#  49  FONTEINV      object
#  50  DTRECEBIM     object
#  51  UFINFORM      float64
#  52  CB_PRE        object
#  53  MORTEPARTO    float64
#  54  DTCADINF      float64
#  55  TPOBITOCOR    float64
#  56  DTCADINV      float64
#  57  COMUNSVOIM    float64
#  58  DTRECORIG     float64
#  59  DTRECORIGA    object
#  60  CAUSAMAT      object
#  61  ESC2010       float64
#  62  ESCMAE2010    float64
#  63  STDOEPIDEM    float64
#  64  STDONOVA      float64
#  65  SEMAGESTAC    float64
#  66  TPMORTEOCO    float64
#  67  DIFDATA       float64
#  68  DTCONCASO     float64
#  69  NUDIASOBIN    float64
#  70  SERIESCFAL    float64
#  71  SERIESCMAE    float64
#  72  CODMUNCART    float64
#  73  CODCART       float64
#  74  NUMREGCART    float64
#  75  DTREGCART     float64
#  76  DTCONINV      float64
#  77  CODMUNNATU    float64
#  78  ESTABDESCR    object
#  79  CRM           object
#  80  NUMEROLOTE    float64
#  81  STCODIFICA    object
#  82  CODIFICADO    object
#  83  VERSAOSIST    object
#  84  VERSAOSCB     float64
#  85  ATESTADO      object
#  86  ESCMAEAGR1    float64
#  87  ESCFALAGR1    float64
#  88  NUDIASOBCO    float64
#  89  FONTES        object
#  90  TPRESGINFO    float64
#  91  TPNIVELINV    object
#  92  NUDIASINF     float64
#  93  FONTESINF     object
#  94  ALTCAUSA      float64
#  95  IDADEminutos  float64
#  96  IDADEhoras    float64
#  97  IDADEdias     float64
#  98  IDADEmeses    float64
#  99  IDADEanos     float64
# dtypes: float64(44), int64(4), object(52)
# memory usage: 3.0+ GB
# None
# CONTADOR              0
# ORIGEM                0
# TIPOBITO              0
# DTOBITO               0
# HORAOBITO        193434
#                  ...
# IDADEminutos    3977796
# IDADEhoras      3970398
# IDADEdias       3940634
# IDADEmeses      3957382
# IDADEanos         94396
# Length: 100, dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\envpowerbi\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DTOBITO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-13e2da39286b> in <module>
#      11
#      12 # Convertendo a coluna 'DTOBITO' para datetime
# ---> 13 data['DTOBITO'] = pd.to_datetime(data['DTOBITO'])
#      14
#      15 # Convertendo a coluna 'SEXO' para valores numéricos (0 para Feminino e 1 para Masculino)
#
# ~\anaconda3\envs\envpowerbi\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~\anaconda3\envs\envpowerbi\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'DTOBITO'

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3982921 entries, 0 to 3982920
# Data columns (total 100 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   CONTADOR      int64
#  1   ORIGEM        int64
#  2   TIPOBITO      object
#  3   DTOBITO       object
#  4   HORAOBITO     object
#  5   NATURAL       object
#  6   DTNASC        object
#  7   SEXO          object
#  8   RACACOR       object
#  9   ESTCIV        object
#  10  ESC           object
#  11  OCUP          object
#  12  CODMUNRES     int64
#  13  CODBAIRES     float64
#  14  LOCOCOR       object
#  15  CODESTAB      float64
#  16  CODMUNOCOR    int64
#  17  CODBAIOCOR    float64
#  18  IDADEMAE      float64
#  19  ESCMAE        object
#  20  OCUPMAE       object
#  21  QTDFILVIVO    float64
#  22  QTDFILMORT    float64
#  23  GRAVIDEZ      object
#  24  GESTACAO      object
#  25  PARTO         object
#  26  OBITOPARTO    object
#  27  PESO          float64
#  28  OBITOGRAV     object
#  29  OBITOPUERP    object
#  30  ASSISTMED     object
#  31  EXAME         object
#  32  CIRURGIA      object
#  33  NECROPSIA     object
#  34  LINHAA        object
#  35  LINHAB        object
#  36  LINHAC        object
#  37  LINHAD        object
#  38  LINHAII       object
#  39  CAUSABAS      object
#  40  DTATESTADO    object
#  41  CIRCOBITO     object
#  42  ACIDTRAB      object
#  43  FONTE         object
#  44  TPPOS         object
#  45  DTINVESTIG    object
#  46  CAUSABAS_O    object
#  47  DTCADASTRO    object
#  48  ATESTANTE     object
#  49  FONTEINV      object
#  50  DTRECEBIM     object
#  51  UFINFORM      float64
#  52  CB_PRE        object
#  53  MORTEPARTO    float64
#  54  DTCADINF      float64
#  55  TPOBITOCOR    float64
#  56  DTCADINV      float64
#  57  COMUNSVOIM    float64
#  58  DTRECORIG     float64
#  59  DTRECORIGA    object
#  60  CAUSAMAT      object
#  61  ESC2010       float64
#  62  ESCMAE2010    float64
#  63  STDOEPIDEM    float64
#  64  STDONOVA      float64
#  65  SEMAGESTAC    float64
#  66  TPMORTEOCO    float64
#  67  DIFDATA       float64
#  68  DTCONCASO     float64
#  69  NUDIASOBIN    float64
#  70  SERIESCFAL    float64
#  71  SERIESCMAE    float64
#  72  CODMUNCART    float64
#  73  CODCART       float64
#  74  NUMREGCART    float64
#  75  DTREGCART     float64
#  76  DTCONINV      float64
#  77  CODMUNNATU    float64
#  78  ESTABDESCR    object
#  79  CRM           object
#  80  NUMEROLOTE    float64
#  81  STCODIFICA    object
#  82  CODIFICADO    object
#  83  VERSAOSIST    object
#  84  VERSAOSCB     float64
#  85  ATESTADO      object
#  86  ESCMAEAGR1    float64
#  87  ESCFALAGR1    float64
#  88  NUDIASOBCO    float64
#  89  FONTES        object
#  90  TPRESGINFO    float64
#  91  TPNIVELINV    object
#  92  NUDIASINF     float64
#  93  FONTESINF     object
#  94  ALTCAUSA      float64
#  95  IDADEminutos  float64
#  96  IDADEhoras    float64
#  97  IDADEdias     float64
#  98  IDADEmeses    float64
#  99  IDADEanos     float64
# dtypes: float64(44), int64(4), object(52)
# memory usage: 3.0+ GB
#            CONTADOR        ORIGEM     CODMUNRES     CODBAIRES      CODESTAB  \
# count  3.982921e+06  3.982921e+06  3.982921e+06  1.625780e+05  3.178489e+06
# mean   4.239461e+05  1.003886e+00  3.534946e+05  9.822008e+03  2.854669e+06
# std    4.405526e+05  8.689333e-02  1.711635e+03  6.947439e+05  1.760583e+06
# min    1.000000e+00  1.000000e+00  3.500000e+05  1.000000e+00  2.100000e+01
# 25%    1.101100e+05  1.000000e+00  3.518800e+05  1.900000e+01  2.078503e+06
# 50%    2.194430e+05  1.000000e+00  3.541400e+05  4.600000e+01  2.082829e+06
# 75%    6.723150e+05  1.000000e+00  3.550300e+05  9.300000e+01  2.786435e+06
# max    1.832527e+06  3.000000e+00  3.557300e+05  1.000000e+08  9.999999e+06
#
#          CODMUNOCOR    CODBAIOCOR     IDADEMAE    QTDFILVIVO    QTDFILMORT  \
# count  3.982921e+06  3.027300e+04  74904.00000  74280.000000  71930.000000
# mean   3.535833e+05  4.180436e+03     27.65074      3.167919      3.009885
# std    5.921780e+03  2.306219e+05      8.69551     13.365796     16.053450
# min    1.100020e+05  1.000000e+00      9.00000      0.000000      0.000000
# 25%    3.519700e+05  1.600000e+01     21.00000      0.000000      0.000000
# 50%    3.543400e+05  4.300000e+01     27.00000      1.000000      0.000000
# 75%    3.550300e+05  8.900000e+01     33.00000      2.000000      1.000000
# max    5.300100e+05  2.222223e+07     99.00000     99.000000     99.000000
#
#        ...    ESCFALAGR1     NUDIASOBCO   TPRESGINFO    NUDIASINF  \
# count  ...  2.697198e+06  113573.000000  4552.000000  5538.000000
# mean   ...  7.036598e+00      87.219295     1.260545   129.631455
# std    ...  4.083052e+00      83.450322     0.566204   106.205131
# min    ...  0.000000e+00       0.000000     1.000000     8.000000
# 25%    ...  2.000000e+00      35.000000     1.000000    61.000000
# 50%    ...  9.000000e+00      70.000000     1.000000   101.000000
# 75%    ...  1.000000e+01     106.000000     1.000000   152.000000
# max    ...  1.200000e+01     810.000000     3.000000   800.000000
#
#            ALTCAUSA  IDADEminutos    IDADEhoras     IDADEdias    IDADEmeses  \
# count  42496.000000   5125.000000  12523.000000  42287.000000  25539.000000
# mean       1.819889     24.726049      6.314861      7.757467      3.686166
# std        0.384284     16.888828      6.076559      7.491815      2.896332
# min        1.000000      1.000000      0.000000      0.000000      1.000000
# 25%        2.000000     10.000000      1.000000      2.000000      1.000000
# 50%        2.000000     24.000000      4.000000      5.000000      3.000000
# 75%        2.000000     39.000000     10.000000     11.000000      5.000000
# max        2.000000     59.000000     23.000000     29.000000     11.000000
#
#           IDADEanos
# count  3.888525e+06
# mean   6.791930e+01
# std    1.846788e+01
# min    0.000000e+00
# 25%    5.700000e+01
# 50%    7.100000e+01
# 75%    8.200000e+01
# max    1.290000e+02
#
# [8 rows x 48 columns]

# %%
df.isnull().sum()
df.duplicated().sum()
for col in df.columns:
    if df[col].dtype == 'object':
        print(df[col].unique())
# Out:
# ['Não Fetal']
# ['2010-07-22' '2010-08-30' '2010-09-25' ... '2022-11-26' '2022-07-28'
#  '2022-07-18']
# ['0700' '1700' '0740' ... '21;00' '05000' '08000']
# [nan 'N INFORMADO' 'MALASIA' 'MARROCOS' 'ARMENIA' 'SEYCHELES' 'MADAGASCAR'
#  'LAOS' 'VIETNA' 'RIO GRANDE DO NORTE' 'SENEGAL' 'TAIWAN (FORMOSA)'
#  'PIAUI' 'TADJIQUISTAO' 'COOK, ILHAS' 'BUTAO' 'SAMOA AMERICANA, ILHAS'
#  'GROENLANDIA' 'ANDORRA' 'HONG KONG' 'EGITO' 'MAURITANIA' 'LIBERIA'
#  'KIRIBATI' 'FALKLAND, ILHAS  (EX-MALVINAS)' 'TANZANIA' 'COMORES, ILHA'
#  'BRUNEI' 'ILHAS MARSHALL' 'GABAO' 'FRANCA' 'ANTIGUA E BARBUDA' 'CONGO'
#  'SAN MARINO' 'JAMAICA' 'GANA' 'GUINE EQUATORIAL' 'TONGA' 'BAHREIN'
#  'LIBIA' 'BURUNDI' 'LIBANO' 'BENIN' 'ANGUILLA' 'DJIBUTI' 'AFEGANISTAO'
#  'CANADA' 'TOCANTINS' 'FINLANDIA' 'AZERBAIDJAO' 'AMAPA' 'ESPANHA'
#  'GRANADA' 'SAMOA' 'MALDIVAS' 'ALEMANHA OC' 'GEORGIA'
#  'ANTILHAS HOLANDESAS' 'LETONIA' 'REPUBLICA DOMINICANA' 'TOGO' 'ISLANDIA'
#  'GRECIA' 'SAO TOME E PRINCIPE' 'SERRA LEOA' 'PAPUA NOVA GUINE'
#  'ILHAS SALOMAO' 'GUIANA' 'CAYMAN, ILHAS' 'FILIPINAS' 'MONACO' 'ARUBA'
#  'MACAU' 'EMIRADOS ARABES UNIDOS' 'REINO UNIDO' 'ARGENTINA' 'HAITI'
#  'ZIMBABUE' 'GUINE-BISSAU' 'CUBA' 'HONDURAS' 'SERGIPE' 'EQUADOR'
#  'PARAGUAI' 'BOLIVIA' 'SRI LANKA' 'COREIA DO NORTE' 'GALES, (PAIS DE)'
#  'TURCOMENISTAO' 'DISTRITO FEDERAL' 'INGLATERRA' 'EL SALVADOR' 'REUNIAO'
#  'BELARUS (OU BIELORRUSSIA)' 'BOTSUANA' 'SUECIA' 'AUSTRIA' 'AMAZONAS'
#  'MADEIRA' 'IRA' 'CINGAPURA' 'ILHAS BRITANICAS' 'NICARAGUA' 'NAURU'
#  'MARTINICA' 'NIGERIA' 'BELGICA' 'ANGOLA' 'INDIA' 'CAMEROON' 'BAHIA'
#  'CHADE' 'CHIPRE' 'ROMENIA' 'SUDAO' 'LIECHTENSTEIN' 'URUGUAI' 'UCRANIA'
#  'RIO GRANDE DO SUL' 'MAYOTTE' 'SANTA CATARINA' 'FIJI'
#  'MIANMAR (OU BIRMANIA)' 'GAMBIA' 'VANUATU' 'SUAZILANDIA'
#  'BOSNIA-HERZEGOVINA' 'INDONESIA' 'EX-IUGOSLAVIA' 'SURINAME' 'ALBANIA'
#  'SOMALIA' 'PERU' 'POLINESIA FRANCESA' 'BANGLADESH' 'ASIA CENTRAL'
#  'NORFOLK, ILHA' 'MATO GROSSO' 'ZAMBIA' 'BRASIL - UF IGN' 'BELIZE' 'OMA'
#  'LUXEMBURGO' 'MAURICIO' 'ITALIA' 'MEXICO' 'QUENIA'
#  'VIRGENS BRITANICAS,ILHAS' 'MONGOLIA' 'HUNGRIA' 'SIRIA' 'DOMINICA'
#  'SUICA' 'PARANA' 'VATICANO' 'ARGELIA' 'COSTA DO MARFIM' 'NOVA ZELANDIA'
#  'MALTA' 'BERMUDAS' 'SAINT PIERRE E MIQUELON,I' 'SAO VICENTE E GRANADINAS'
#  'GIBRALTAR' 'SAARA OCIDENTAL' 'REPUBLICA DEMOCRATICA DO CONGO' 'IRAQUE'
#  'ESLOVAQUIA' 'MARANHAO' 'UZBEQUISTAAO' 'JAPAO' 'MACEDONIA' 'MAN, ILHA DE'
#  'TURQUIA' 'PALAU' 'REPUBLICA CENTRO-AFRICANA' 'MOCAMBIQUE' 'MINAS GERAIS'
#  'WALLIS, ILHA' 'ESPIRITO SANTO' 'TAILANDIA']
# ['1933-01-18' '1945-11-05' '1938-05-26' ... '2005-03-25' '2007-12-04'
#  '2006-11-17']
# ['Masculino' 'Feminino' nan]
# ['Branca' 'Preta' 'Amarela' nan 'Parda' 'Indígena']
# ['Casado' 'Solteiro' 'Viúvo' 'União consensual' nan
#  'Separado judicialmente']
# ['4 a 7 anos' '12 anos ou mais' '8 a 11 anos' '1 a 3 anos' 'Nenhuma' nan]
# ['Aposentado/Pensionista' 'Pedagogo' 'Comerciante varejista' ...
#  'Enfermeiro psiquiátrico'
#  'Operador de motoniveladora (extração de minerais só' 'Malabarista']
# ['Domicílio' 'Outros' 'Hospital' 'Outro estabelecimento de saúde'
#  'Via pública' nan]
# [nan '8 a 11 anos' '12 anos ou mais' '4 a 7 anos' 'Nenhuma' '1 a 3 anos']
# ['Nao informada' 'Dona de Casa' 'Auxiliar de pessoal' 'Advogado'
#  'Técnico de enfermagem' 'Trabalhador volante da agricultura'
#  'Professor de nível médio no ensino fundamental' 'Estudante'
#  'Comerciante varejista' 'Auxiliar de enfermagem'
#  'Atendente de farmácia - balconista' 'Promotor de vendas'
#  'Empregado doméstico nos serviços gerais' 'Administrador'
#  'Empregado doméstico diarista' 'Vendedor de comércio varejista'
#  'Professor de nível superior na educação infantil (q'
#  'Operador de telemarketing ativo' 'Manicure' 'Comerciante atacadista'
#  'Recepcionista, em geral' 'Assistente administrativo'
#  'Operador de telemarketing ativo e receptivo' 'Cabeleireiro' 'Ignorada'
#  'Professor da educação de jovens e adultos do ensino'
#  'Alimentador de linha de produção' 'Trabalhador agropecuário em geral'
#  'Auxiliar de escritório, em geral' 'Bibliotecário'
#  'Auxiliar de Prótese Dentária' 'Ceramista'
#  'Costureira de peças sob encomenda' 'Digitador'
#  'Costureiro na confecção em série' 'Costureiro de roupa de couro e pele'
#  'Operador de caixa' 'Babá' 'Inspetor de alunos de escola pública'
#  'Cozinheiro geral' 'Químico' 'Técnico químico' 'Biólogo'
#  'Professor de educação artística do ensino fundament' 'Psicólogo clínico'
#  'Fisioterapeuta' 'Faxineiro' 'Operador de máquinas operatrizes'
#  'Missionário' 'Mordomo de hotelaria'
#  'Desempregado cronico ou cuja habitação habitual' 'Chefe de confeitaria'
#  'Pedagogo' 'Cozinheiro do serviço doméstico'
#  'Empregado doméstico faxineiro' 'Aposentado/Pensionista'
#  'Agente publicitário' 'Auxiliar de serviços de importação e exportação'
#  'Supervisor de orçamento' 'Operador de máquinas-ferramenta convencionais'
#  'Enfermeiro' 'Auxiliar de serviços jurídicos' 'Instrutor de auto-escola'
#  'Nutricionista' 'Desenhista industrial (designer)'
#  'Trabalhador polivalente da confecção de calçados'
#  'Sapateiro (calçados sob medida)' 'Agente de segurança'
#  'Inspetor de qualidade' 'Analista financeiro (instituições financeiras)'
#  'Monitor de teleatendimento' 'Magarefe' 'Auxiliar de lavanderia'
#  'Atendente de agência' 'Atendente comercial (agência postal)'
#  'Protético dentário' 'Atendente de lanchonete'
#  'Costureira de reparação de roupas' 'Supervisor de vendas comercial'
#  'Cuidador de idosos' 'Secretária executiva' 'Caixa de banco'
#  'Agente de saúde pública' 'Assistente comercial de seguros'
#  'Auxiliar de faturamento' 'Trabalhador da manutenção de edificações'
#  'Oleiro (fabricação de tijolos)' 'Gerente de restaurante'
#  'Representante comercial autônomo' 'Agente comunitário de saúde'
#  'Auxiliar de desenvolvimento infantil'
#  'Auxiliar de corte (preparação da confecção de roupa' 'Copeiro'
#  'Professor de nível superior do ensino fundamental ('
#  'Técnico de operações e serviços bancários - renda f' 'Ourives'
#  'Preparador de esmaltes (cerâmica)'
#  'Professor de história no ensino médio' 'Médico cirurgião geral'
#  'Chefe de contabilidade (técnico)' 'Guarda-civil municipal'
#  'Trabalhador de preparação de pescados (limpeza)'
#  'Auxiliar de contabilidade' 'Professor de matemática no ensino médio'
#  'Ajudante de despachante aduaneiro' 'Gerente administrativo'
#  'Escriturário de banco' 'Analista de desenvolvimento de sistemas'
#  'Recepcionista de consultório médico ou dentário' 'Jardineiro'
#  'Recepcionista de hotel' 'Papiloscopista policial'
#  'Analista de cobrança (instituições financeiras)'
#  'Gerente de departamento pessoal' 'Farmacêutico' 'Ajudante de motorista'
#  'Costureiro, a máquina na confecção em série'
#  'Operador de linha de montagem (aparelhos eletrônico' 'Gerente comercial'
#  'Vendedor em comércio atacadista' 'Empresário de espetáculo'
#  'Tosador de animais domésticos' 'Caseiro (agricultura)' 'Cumim'
#  'Técnico em secretariado'
#  'Analista de informações (pesquisador de informações'
#  'Gerente de loja e supermercado' 'Despachante aduaneiro'
#  'Corretor de imóveis' 'Feirante' 'Empregado doméstico arrumador'
#  'Vendedor ambulante' 'Professor de nível médio na educação infantil' nan
#  'Especialista em pesquisa operacional' 'Camareiro de hotel'
#  'Professor de disciplinas pedagógicas no ensino médi' 'Almoxarife'
#  'Dirigente do serviço público municipal'
#  'Despachante de transportes coletivos (exceto trem)' 'Teleoperador'
#  'Analista de sistemas de automação'
#  'Auxiliar geral de conservação de vias permanentes ('
#  'Auxiliar de produção farmacêutica' 'Vigilante'
#  'Encarregado de costura na confecção do vestuário'
#  'Professores de cursos livres' 'Passador de roupas em geral'
#  'Operador de máquinas fixas, em geral' 'Analista de recursos humanos'
#  'Cirurgião dentista - clínico geral' 'Engenheiro eletricista' 'Frentista'
#  'Zelador de edifício' 'Terapeuta ocupacional' 'Médico clínico'
#  'Assistente de vendas' 'Vigia' 'Analista de produtos bancários'
#  'Engenheiro civil' 'Auxiliar de farmácia de manipulação'
#  'Orientador educacional'
#  'Costureiro de roupas de couro e pele, a máquina na' 'Garçom'
#  'Consultor jurídico' 'Economista' 'Lavador de roupas'
#  'Oficial do registro de títulos e documentos'
#  'Operador de inspeção de qualidade' 'Apontador de produção'
#  'Encarregado de corte na confecção do vestuário' 'Porteiro de edifícios'
#  'Biotecnologista' 'Assistente social'
#  'Analista de crédito (instituições financeiras)'
#  'Diretor de produção e operações da indústria de tra'
#  'Montador de equipamentos elétricos'
#  'Professor de educação física no ensino médio'
#  'Fiscal de transportes coletivos (exceto trem)'
#  'Gerente de recursos humanos' 'Catador de material reciclável'
#  'Conferente-expedidor de roupas (lavanderias)' 'Engenheiro químico'
#  'Operador de máquina copiadora (exceto operador de g'
#  'Analista de sinistros' 'Gerente de vendas'
#  'Acabador de embalagens (flexíveis e cartotécnicas)' 'Revisor'
#  'Redator de publicidade' 'Auditor (contadores e afins)' 'Arrematadeira'
#  'Gerente financeiro' 'Professor prático no ensino profissionalizante'
#  'Professor de nível médio no ensino profissionalizan' 'Técnico agrícola'
#  'Esteticista' 'Promotor de justiça' 'Comprador'
#  'Professor leigo no ensino fundamental' 'Escrevente'
#  'Instrumentador cirúrgico' 'Artista (artes visuais)'
#  'Designer de interiores'
#  'Corretor de valores, ativos financeiros, mercadoria'
#  'Supervisor de telemarketing e atendimento'
#  'Professor de ciências exatas e naturais do ensino f'
#  'Operador de telemarketing técnico' 'Atendente de Consultório Dentário'
#  'Lavadeiro, em geral' 'Editor de texto e imagem'
#  'Supervisor de crédito e cobrança' 'Técnico em administração'
#  'Trabalhador de tratamento do leite e fabricação de' 'Agente de viagem'
#  'Conferente de serviços bancários'
#  'Diretor geral de empresa e organizações (exceto de'
#  'Enfermeiro obstétrico' 'Operador de cobrança bancária'
#  'Arquiteto de edificações' 'Chefe de portaria de hotel'
#  'Cozinhador de carnes' 'Apresentador de programas de rádio'
#  'Médico homeopata' 'Carteiro' 'Confeiteiro' 'Chefe de cozinha'
#  'Gerente de logística (armazenagem e distribuição)' 'Jornalista'
#  'Contador' 'Montador de equipamentos eletrônicos'
#  'Escriturário em estatística' 'Designer de vitrines'
#  'Chefe de serviços bancários' 'Repositor de mercadorias'
#  'Operador de telemarketing receptivo' 'Promotor de vendas especializado'
#  'Governanta de hotelaria' 'Técnico em segurança no trabalho' 'Sociólogo'
#  'Secretário - Executivo' 'Músico intérprete instrumentista'
#  'Técnico de laboratório industrial' 'Analista de pesquisa de mercado'
#  'Cobrador de transportes coletivos (exceto trem)' 'Massagista'
#  'Coordenador pedagógico' 'Vendedor em domicílio'
#  'Auxiliar técnico em patologia clínica'
#  'Cirurgião dentista de saúde coletiva'
#  'Marcador de produtos (siderúrgico e metalúrgico)' 'Oficial de justiça'
#  'Cortador de tapeçaria' 'Trabalhador da cultura de cana-de-açúcar'
#  'Operador de máquina bordatriz' 'Fonoaudiólogo'
#  'Agente fiscal de qualidade'
#  'Auxiliar de laboratório de análises clínicas'
#  'Professor de ensino superior na área de didática'
#  'Atendente de enfermagem' 'Técnico de garantia da qualidade'
#  'Locutor publicitário de rádio e televisão' 'Tecelão (redes)'
#  'Agente de vendas de serviços' 'Fiscal de tributos municipal'
#  'Cobrador interno' 'Técnico em atendimento e vendas' 'Relações públicas'
#  'Professor de artes do espetáculo no ensino superior'
#  'Conferente de carga e descarga' 'Padeiro' 'Organizador de evento'
#  'Engenheiro naval' 'Técnico operacional de serviços de correios'
#  'Médico veterinário' 'Modelo publicitário'
#  'Operador de produção (química, petroquímica e afins'
#  'Auxiliar de cartório' 'Auxiliar de laboratório de imunobiológicos'
#  'Técnico de apoio ao usuário de informática (helpdes'
#  'Operador de atendimento aeroviário' 'Passadeira de peças confeccionadas'
#  'Montador de máquinas' 'Técnico de contabilidade' 'Gerente de hotel'
#  'Motorista de caminhão (rotas regionais e internacio'
#  'Operador de caldeira' 'Escrivão de polícia' 'Técnico de vendas'
#  'Arquiteto urbanista' 'Embalador, a mão'
#  'Supervisor de caixas e bilheteiros (exceto caixa de'
#  'Vendedor permissionário' 'Professor de artes no ensino médio'
#  'Consultor contábil (técnico)' 'Desenhista copista' 'Zootecnista'
#  'Supervisor de almoxarifado' 'Tecelão de malhas, a máquina'
#  'Delegado de polícia' 'Soldador'
#  'Operador de máquina de costura de acabamento' 'Gerente de compras'
#  'Podólogo' 'Vistoriador naval' 'Motorista de ônibus urbano'
#  'Técnico mecânico na fabricação de ferramentas' 'Tecnólogo em eletrônica'
#  'Fotógrafo' 'Telefonista' 'Açougueiro'
#  'Trabalhador no cultivo de árvores frutíferas' 'Projetista de móveis'
#  'Técnico de manutenção eletrônica' 'Cozinhador de frutas e legumes'
#  'Corretor de seguros'
#  'Trabalhador de serviços de manutenção de edifícios'
#  'Técnico de telecomunicações (telefonia)' 'Atendente de judiciário'
#  'Gerente de serviços culturais'
#  'Professor de ensino superior na área de prática de' 'Escritor de ficção'
#  'Produtor agrícola polivalente'
#  'Supervisor de fabricação de produtos cerâmicos, por'
#  'Técnico têxtil (tratamentos químicos)'
#  'Instalador de som e acessórios de veículos' 'Tesoureiro de banco'
#  'Agente de higiene e segurança'
#  'Entrevistador de pesquisa de opinião e mídia'
#  'Professor de educação física do ensino fundamental' 'Comissário de vôo'
#  'Guardador de veículos'
#  'Operador de computador (inclusive microcomputador)'
#  'Técnico em manutenção de equipamentos de informátic'
#  'Supervisor administrativo' 'Recepcionista de banco' 'Ascensorista'
#  'Analista de câmbio' 'Inspetor de alunos de escola privada'
#  'Assistente técnico de seguros' 'Gerente de comunicação'
#  'Estatístico (estatística aplicada)' 'Psicólogo social' 'Gari'
#  'Operador de máquina de fabricação de produtos de hi'
#  'Modelista de roupas' 'Professor de física no ensino médio'
#  'Instrutor de aprendizagem e treinamento industrial'
#  'Professor de língua e literatura brasileira no ensi'
#  'Agente de estação (ferrovia e metrô)' 'Analista de seguros (técnico)'
#  'Maquiador' 'Analista de exportação e importação' 'Guia de turismo'
#  'Professor de administração' 'Psicopedagogo' 'Técnico têxtil'
#  'Assessor de imprensa'
#  'Professor instrutor de ensino e aprendizagem em ser'
#  'Professor de psicologia no ensino médio'
#  'Analista de redes e de comunicação de dados' 'Diretor administrativo'
#  'Músico intérprete cantor' 'Professor de dança' 'Malabarista'
#  'Classificador de couros'
#  'Professor de educação física no ensino superior'
#  'Professor de língua portuguesa' 'Ajudante de carvoaria'
#  'Fiscal de pátio de usina de concreto' 'Misturador de café'
#  'Analista de negócios' 'Analista de suporte computacional'
#  'Técnico de operações e serviços bancários - câmbio'
#  'Operador de empilhadeira' 'Operador de máquina de etiquetar'
#  'Decorador de interiores de nível superior'
#  'Cozinhador (conservação de alimentos)' 'Recreador'
#  'Supervisor de cobrança' 'Técnico de planejamento de produção'
#  'Técnico em laboratório de farmácia' 'Gerente de produtos bancários'
#  'Gerente de grandes contas (corporate)' 'Secretário bilíngüe'
#  'Motorista de carro de passeio' 'Economista do setor público'
#  'Técnico em radiologia e imagenologia'
#  'Trabalhador da avicultura de corte' 'Contínuo' 'Técnico eletrônico'
#  'Desenhista projetista de arquitetura'
#  'Professor de história do ensino fundamental' 'Coletor de lixo'
#  'Copeiro de hospital' 'Agente de trânsito' 'Operador de bobinadeira'
#  'Diretor de instituição educacional da área privada' 'Leiturista'
#  'Cobrador externo' 'Atendente de lavanderia'
#  'Operador de time de montagem' 'Auxiliar de maquinista de trem'
#  'Limpador de vidros' 'Dirigente do serviço público federal'
#  'Gerente de suporte técnico de tecnologia da informa'
#  'Auxiliar de laboratório de análises físico-químicas'
#  'Encarregado geral de operações de conservação de vi'
#  'Gravador, à mão (encadernação)'
#  'Diretor de produção e operações de turismo' 'Técnico de saneamento'
#  'Agente de recrutamento e seleção' 'Programador de internet'
#  'Dirigente do serviço público estadual e distrital'
#  'Técnico de laboratório de análises físico-químicas'
#  'Artesão modelador (vidros)' 'Trabalhador no cultivo de mudas'
#  'Técnico de operações e serviços bancários - crédito'
#  'Cozinhador de pescado' 'Técnico de comunicação de dados'
#  'Apontador de mão-de-obra' 'Jornaleiro (em banca de jornal)'
#  'Instrutor de cursos livres' 'Vassoureiro' 'Líder de comunidade caiçara'
#  'Gerente de serviços sociais' 'Profissional do sexo'
#  'Auxiliar de biblioteca' 'Editor'
#  'Engenheiros de sistemas operacionais em computação'
#  'Auxiliar de enfermagem do trabalho' 'Supervisor de tesouraria'
#  'Engenheiro civil (aeroportos)'
#  'Diretor de operações comerciais (comércio atacadist'
#  'Professor de artes visuais no ensino superior (arte'
#  'Restaurador de livros' 'Arquiteto de interiores' 'Ator'
#  'Diretor de marketing' 'Gerente de projetos e serviços de manutenção'
#  'Operador de triagem e transbordo' 'Cozinheiro de hospital'
#  'Técnico em óptica' 'Supervisor de embalagem e etiquetagem'
#  'Controlador de serviços de máquinas e veículos'
#  'Professor de geografia no ensino médio'
#  'Professor de nível superior na educação infantil (z'
#  'Professor de língua portuguesa do ensino fundamenta'
#  'Gerente de crédito e cobrança' 'Supervisor de vendas de serviços'
#  'Montador de equipamentos eletrônicos (computadores'
#  'Demonstrador de mercadorias' 'Motorista de furgão ou veículo similar'
#  'Técnico de tributos municipal' 'Bilheteiro de transportes coletivos'
#  'Masseiro (massas alimentícias)' 'Camareira de teatro'
#  'Técnico de alimentos' 'Atleta profissional (outras modalidades)'
#  'Estampador de tecido' 'Macheiro, a mão' 'Técnico agropecuário'
#  'Trabalhador na produção de mudas e sementes' 'Borracheiro'
#  'Operador de cortadeira de papel' 'Pedreiro'
#  'Operador de acabamento (indústria gráfica)' 'Médico dermatologista'
#  'Supervisor de entrevistadores e recenseadores' 'Arquiteto paisagista'
#  'Gerente de marketing' 'Armazenista'
#  'Professor de biologia no ensino médio' 'Controlador de tráfego aéreo'
#  'Professor de ciências biológicas do ensino superior'
#  'Encarregado de manutenção mecânica de sistemas oper'
#  'Entrevistador de pesquisas de mercado'
#  'Engenheiro de segurança do trabalho' 'Médico alergista e imunologista'
#  'Desenhista técnico (artes gráficas)' 'Professor de contabilidade'
#  'Supervisor de recepcionistas' 'Dançarino popular'
#  'Procurador da assistência judiciária' 'Tecelão (rendas e bordados)'
#  'Foguista (locomotivas a vapor)' 'Comissário de trem'
#  'Moldador de plástico por injeção' 'Operador de painel de controle'
#  'Vendedor pracista' 'Despachante documentalista'
#  'Agente de polícia federal' 'Controlador de entrada e saída'
#  'Ministro de culto religioso' 'Engenheiro florestal'
#  'Operador de máquinas de fabricação de doces, salgad'
#  'Costurador de calçados, a máquina' 'Diretor comercial'
#  'Assistente de coreografia' 'Médico psiquiatra'
#  'Montador de andaimes (edificações)'
#  'Professor de pesquisa operacional (no ensino superi'
#  'Agente de proteção de aeroporto' 'Professor de língua inglesa'
#  'Cozinheiro de embarcações' 'Diretor de relações de trabalho'
#  'Servente de obras' 'Gerente de agência'
#  'Eletricista de instalações (edifícios)'
#  'Operador de linha de montagem (aparelhos elétricos)'
#  'Apresentador de eventos' 'Decorador de cerâmica'
#  'Professor de arquitetura' 'Analista de transporte em comércio exterior'
#  'Professor de técnicas de enfermagem'
#  'Gerente de contas - pessoa física e jurídica'
#  'Produtor agropecuário, em geral' 'Ligador de linhas telefônicas'
#  'Degustador de vinhos ou licores'
#  'Engenheiro de equipamentos em computação' 'Defensor público'
#  'Gravador de matriz serigráfica'
#  'Caminhoneiro autônomo (rotas regionais e internacio'
#  'Cozinheiro industrial' 'Despachante operacional de vôo'
#  'Recepcionista de casas de espetáculos'
#  'Bailarino (exceto danças populares)' 'Gerente de bar'
#  'Trabalhador da exploração de babaçu' 'Técnico de seguros'
#  'Técnico em administração de comércio exterior'
#  'Programador de sistemas de informação'
#  'Professor de serviço social do ensino superior'
#  'Montador de móveis e artefatos de madeira' 'Ciclista mensageiro'
#  'Engenheiro mecânico' 'Perfumista'
#  'Gerente de operações de correios e telecomunicações' 'Antropólogo'
#  'Bordador, à máquina' 'Guarda-roupeira de cinema'
#  'Professor de matemática do ensino fundamental'
#  'Porteiro de locais de diversão' 'Técnico da receita federal'
#  'Passador de roupas, à mão' 'Supervisor de transportes'
#  'Policial rodoviário federal' 'Cirurgião dentista - auditor'
#  'Operador de centro de controle' 'Desenhista técnico (indústria têxtil)'
#  'Técnico de enfermagem de terapia intensiva' 'Auditor-fiscal do trabalho'
#  'Pintor de obras' 'Tratorista agrícola' 'Gerente de produção e operações'
#  'Kardexista' 'Pescador artesanal de água doce' 'Advogado (direito civil)'
#  'Prensista de compensados' 'Supervisor de compras'
#  'Tecelão (tear manual)' 'Gerente de projetos de tecnologia da informação'
#  'Diretor de serviços de informática' 'Operador de transporte multimodal'
#  'Auxiliar de estatística' 'Músico arranjador' 'Supervisor de lavanderia'
#  'Professor de sociologia do ensino superior' 'Impressor digital'
#  'Supervisor de produção na mineração' 'Montador de calçados'
#  'Recepcionista de seguro saúde' 'Investigador de polícia' 'Tradutor'
#  'Modelo de modas' 'Economista ambiental' 'Dietista'
#  'Banhista de animais domésticos' 'Gerente de almoxarifado'
#  'Gerente de riscos' 'Diretor financeiro' 'Arquivista de documentos'
#  'Operador de passador (fiação)'
#  'Gerente de captação (fundos e investimentos institu'
#  'Técnico de enfermagem psiquiátrica'
#  'Trabalhador da pecuária (asininos e muares)'
#  'Agente de segurança penitenciária' 'Visitador sanitário'
#  'Técnico têxtil de tecelagem' 'Diretor administrativo e financeiro'
#  'Bordador, a mão' 'Técnico em higiene dental'
#  'Gerente de segurança de tecnologia da informação' 'Alfaiate'
#  'Técnico em turismo' 'Operador de negócios' 'Editor de TV e vídeo'
#  'Trabalhador de extração florestal, em geral' 'Sepultador'
#  'Pesquisador em psicologia' 'Bilheteiro no serviço de diversões'
#  'Administrador de edifícios' 'Pesquisador em saúde coletiva'
#  'Bombeiro de segurança do trabalho' 'Localizador (cobrador)'
#  'Operador de forno (fabricação de pães, biscoitos e' 'Tabelião de notas'
#  'Médico cardiologista' 'Geólogo' 'Detetive profissional'
#  'Médico citopatologista' 'Barman' 'Revisor de fios (produção têxtil)'
#  'Lavador de roupas a maquina'
#  'Costurador de artefatos de couro, a máquina (exceto'
#  'Trabalhador no cultivo de flores em vaso'
#  'Operador de mensagens de telecomunicações (correios'
#  'Adestrador de animais' 'Diretor de recursos humanos' 'Marceneiro'
#  'Procurador do município' 'Montador de máquinas têxteis'
#  'Acabador de calçados' 'Químico industrial'
#  'Técnico em patologia clínica' 'Preparador de calçados'
#  'Produtor cinematográfico' 'Agente de pátio'
#  'Técnico em manutenção de máquinas' 'Mãe social'
#  'Agenciador de propaganda' 'Operador de áudio de continuidade (rádio)'
#  'Diretor de produtos bancários' 'Montador de filmes' 'Neuropsicólogo'
#  'Trabalhador da suinocultura' 'Trabalhador da ovinocultura'
#  'Professor de física (ensino superior)'
#  'Revelador de filmes fotográficos, em cores' 'Limpador a seco, à máquina'
#  'Engenheiro metalurgista'
#  'Operador de máquina de usinagem de madeira (produçã' 'Metrologista'
#  'Tecelão de tapetes, a mão'
#  'Inspetor de serviços de transportes rodoviários (pa'
#  'Supervisor de andar' 'Estatístico'
#  'Cirurgião dentista - odontologista legal' 'Engenheiro de pesca'
#  'Trabalhador da avicultura de postura' 'Produtor de televisão'
#  'Professor de ciência política do ensino superior'
#  'Professor de enfermagem do ensino superior' 'Esterilizador de alimentos'
#  'Desenhista técnico (arquitetura)' 'Abatedor'
#  'Operador de processo (química, petroquímica e afins'
#  'Camareira de televisão' 'Impressor de ofsete (plano e rotativo)'
#  'Auxiliar de radiologia (revelação fotográfica)' 'Perito contábil'
#  'Auditor-fiscal da receita federal' 'Engenheiro de produção'
#  'Prensista (operador de prensa)'
#  'Professor de geografia do ensino fundamental' 'Joalheiro'
#  'Operador de transferência e estocagem - na refinaçã'
#  'Administrador de banco de dados'
#  'Operador de máquina centrifugadora de fundição'
#  'Chefe de serviço de transporte rodoviário (passagei'
#  'Técnico de operações e serviços bancários - leasing'
#  'Auxiliar de judiciário'
#  'Operador de máquinas do acabamento de couros e pele'
#  'Locutor de rádio e televisão' 'Escrivão judicial'
#  'Auxiliar de banco de sangue' 'Pesquisador em química'
#  'Auxiliar de saúde (navegação marítima)'
#  'Professor de aprendizagem e treinamento comercial'
#  'Embalador, a máquina'
#  'Mecânico de manutenção de automóveis, motocicletas'
#  'Supervisor técnico operacional de sistemas de telev'
#  'Supervisor de ensino' 'Administrador de sistemas operacionais'
#  'Revisor de tecidos crus' 'Assistente de laboratório industrial'
#  'Professor de química no ensino médio' 'Economista financeiro'
#  'Eletrotécnico' 'Trabalhador do acabamento de artefatos de tecidos e'
#  'Geógrafo' 'Diretor de redação'
#  'Montador de artefatos de couro (exceto roupas e cal'
#  'Agente de defesa ambiental' 'Técnico de controle de meio ambiente'
#  'Professor de nutrição'
#  'Administrador de fundos e carteiras de investimento'
#  'Tratador de animais' 'Técnico em instrumentação'
#  'Pesquisador em biologia de microorganismos e parasi'
#  'Diretor de planejamento estratégico' 'Preparador físico'
#  'Atleta profissional de luta' 'Secretária trilíngüe' 'Monotipista'
#  'Encarregado de equipe de conservação de vias perman'
#  'Engenheiro aeronáutico' 'Condutor de veículos a pedais'
#  'Pesquisador em física' 'Médico cirurgião cardiovascular'
#  'Emissor de passagens'
#  'Bilheteiro (estações de metrô, ferroviárias e assem'
#  'Psicólogo do esporte'
#  'Motociclista no transporte de documentos e pequenos'
#  'Gerente de operações de transportes' 'Desenhista técnico'
#  'Técnico de obras civis' 'Avicultor' 'Revisor de tecidos acabados'
#  'Médico cirurgião de cabeça e pescoço' 'Engenheiro agrônomo'
#  'Técnico gráfico' 'Fiscal de tributos estadual'
#  'Técnico de planejamento e programação da manutenção'
#  'Entrevistador censitário e de pesquisas amostrais' 'Bioengenheiro'
#  'Lixador de couros e peles' 'Balanceiro' 'Seringueiro'
#  'Técnico de imobilização ortopédica' 'Operador de máquina de cordoalha'
#  'Operador de quadro de distribuição de energia elétr'
#  'Funileiro industrial' 'Pescador profissional' 'Acupunturista'
#  'Montador de estruturas metálicas'
#  'Gerente de produção de tecnologia da informação' 'Mordomo de residência'
#  'Visual merchandiser' 'Catador de mariscos'
#  'Pesquisador de clínica médica'
#  'Diretor de instituição educacional pública' 'Médico angiologista'
#  'Engenheiro agrícola' 'Intérprete' 'Operador de abertura (fiação)'
#  'Motorista de táxi' 'Pesquisador de engenharia e tecnologia (outras área'
#  'Planejista' 'Supervisor de digitação e operação' 'Auxiliar de seguros'
#  'Mantenedor de sistemas eletroeletrônicos de seguran'
#  'Gerente de clientes especiais (private)' 'Cenógrafo de eventos'
#  'Professor de música no ensino superior' 'Arquivista'
#  'Farmacêutico bioquímico' 'Supervisor de vigilantes'
#  'Curtidor (couros e peles)' 'Engenheiro de aplicativos em computação'
#  'Operador de acabamento de peças fundidas' 'Cartazeiro'
#  'Auxiliar técnico em laboratório de farmácia'
#  'Supervisor (indústria de calçados e artefatos de co'
#  'Técnico em calibração' 'Porteiro (hotel)' 'Operador de laminador'
#  'Economista agroindustrial' 'Técnico florestal' 'Manobrador'
#  'Técnico em mecatrônica - automação da manufatura'
#  'Supervisor da administração de aeroportos'
#  'Mecânico de manutenção de veículos ferroviários'
#  'Pintor de cerâmica, a pincel' 'Gerente de suprimentos'
#  'Professor de fisioterapia' 'Operador de turismo' 'Técnico mecânico'
#  'Limpador de fachadas' 'Técnico de transmissão (telecomunicações)'
#  'Mecânico de manutenção de bomba injetora (exceto de'
#  'Cartonageiro, a máquina' 'Enfermeiro de terapia intensiva'
#  'Operador de desempenadeira na usinagem convencional'
#  'Técnico de manutenção de sistemas e instrumentos'
#  'Desenhista técnico (cartografia)' 'Chapeador'
#  'Professor da área de meio ambiente' 'Operador de maçaroqueira'
#  'Professor de língua francesa' 'Maquiador de caracterização'
#  'Operador de colheitadeira' 'Cirurgião dentista - endodontista'
#  'Professor de alunos com deficiência mental' 'Editor de livro'
#  'Revelador de filmes fotográficos, em preto e branco'
#  'Operador de máquina de dobrar chapas'
#  'Ouvidor (ombudsman) do meio de comunicação'
#  'Operador de rede de teleprocessamento'
#  'Supervisor de montagem e instalação eletroeletrônic'
#  'Psicólogo hospitalar' 'Enfermeiro neonatologista'
#  'Escritor de não ficção' 'Diretor de câmbio e comércio exterior'
#  'Controlador de pragas' 'Desenhista projetista de construção civil'
#  'Operador de máquina de produtos farmacêuticos' 'Desenhista detalhista'
#  'Técnico de enfermagem do trabalho' 'Barbeiro'
#  'Técnico de rede (telecomunicações)'
#  'Pesquisador em ciências da computação e informática' 'Vigia portuário'
#  'Trabalhador de pecuária polivalente' 'Pesquisador em história'
#  'Cortador de artefatos de couro (exceto roupas e cal' 'Documentalista'
#  'Analista de leasing' 'Ma\x8ctre' 'Médico generalista'
#  'Drageador (medicamentos)' 'Atuário'
#  'Técnico de manutenção elétrica de máquina' 'Produtor de flores em vaso'
#  'Enfermeiro veterinário' 'Dirigente de partido político'
#  'Médico otorrinolaringologista'
#  'Produtor na olericultura de talos, folhas e flores'
#  'Enfermeiro do trabalho' 'Arquiteto de patrimônio' 'Meteorologista'
#  'Tecelão (tear automático)' 'Agente de direitos autorais' 'Cronoanalista'
#  'Professor de computação (no ensino superior)'
#  'Torneiro (lavra de pedra)' 'Eletrotécnico (produção de energia)'
#  'Agente fiscal têxtil' 'Domador de animais (circense)'
#  'Trabalhador da pecuária (bovinos corte)' 'Psicanalista']
# [nan 'única' 'Dupla' 'Tríplice e mais']
# [nan '37 a 41 semanas' '22 a 27 semanas' '32 a 36 semanas'
#  '28 a 31 semanas' 'Menos de 22 semanas' '42 semanas e mais']
# [nan 'Cesáreo' 'Vaginal']
# [nan 'Depois' 'Antes' 'Durante']
# [nan 'Não' 'Sim']
# [nan 'Não' 'De 43 dias a 1 ano' 'De 0 a 42 dias']
# [nan 'Sim' 'Não']
# ['Sim' nan 'Não']
# [nan 'Sim' 'Não']
# [nan 'Não' 'Sim']
# ['*R092' '*C80X' '*I219' ... '*N849' '*E550' '*P261*P53X']
# ['*J180' '*C780' '*I255' ... '*R889' '*S068*S090' '*X090*X470']
# [nan '*C787' '*I10X' ... '*E877*E878' '*S423*S521' '*R58X*C329']
# [nan '*C169' '*E149' ... '*K219*K449' '*B94X' '*I110*J449']
# [nan '*F172' '*B24X*I10' ... '*K259*I10X*M799*H259' '*Y830*N289*B449'
#  '*L97X*E14X']
# ['J180' 'C169' 'I219' ... 'E530' 'V417' 'X168']
# ['2010-07-22' '2010-08-30' '2010-09-25' ... '2023-08-10' '2023-07-09'
#  '2023-06-19']
# [nan 'Suicídio' 'Acidente' 'Homicídio' 'Outro']
# [nan 'Não' 'Sim']
# [nan 'Boletim de Ocorrência' 'Outro' 'Família' 'Hospital']
# [nan 'Não investigado' 'Investigado']
# [nan '2010-07-07' '2010-11-10' ... '2023-09-04' '2023-08-19' '2023-09-30']
# ['J180' 'C169' 'I219' ... 'T820' 'G544' 'X168']
# ['2010-07-28' '2010-09-14' '2010-10-13' ... '2023-10-17' '2023-06-22'
#  '2023-10-10']
# ['Sim' 'Substituto' 'Outro' 'IML' nan 'SVO']
# [nan 'Comitê de Mortalidade Materna e/ou Infantil'
#  'Estabelecimento de saúde / Prontuário' 'Múltiplas fontes'
#  'Visita familiar / Entrevista família' 'Outra fonte' 'IML'
#  'Relacionamento com outros bancos de dados' 'SVO']
# ['2010-08-30' '2010-10-13' '2010-10-27' ... '2022-12-20' '2023-06-19'
#  '2022-06-06']
# ['J180' 'C169' 'I219' ... 'E052' 'V798' 'C212']
# [nan '2011-08-31' '2011-11-11' ... '2023-10-19' '2023-06-15' '2022-06-06']
# [nan 'O936' 'O930' 'O937' 'O938' 'O933' 'O939' 'O931' 'O934']
# [nan 'HOSPITAL SAO VICENTE' 'SANTA CASA DESTA CIDADE'
#  'SANTA CASA DE MISERICORDIA' 'UPA - SACADURA CABRAL' 'HOSPITAL SALVALUS'
#  'HOSPITAL GERAL PREFEITO MIGUEL MARTIN GU'
#  'UNIDADE MISTA DE SAUDE SANTA CRUZ' 'HOSPITAL MUNICIPAL DR. GUIDO GUIDA'
#  'PRONTO SOCORRO' 'HOSPITAL BRIGADEIRO'
#  'IRMANDADE DA SANTA CASA DE MISERICORDIA' 'SEU  NA RUA AMAPA'
#  'UNIDADE BASICA DE SAUDE III' 'HOSPITAL DE BASE' 'PRONTO ATENDIMENTO'
#  'HOSPITAL GERAL JESUS TEIXEIRA DA COSTA' 'HOSPITAL MUNICIPAL CAMPO LIMPO'
#  'UPA - UNIDADE DE PRONTO ATENDIMENTO' 'A RUA LUIZ TEIXEIRA'
#  'FRANCISCO ROSAS' 'NESTE MUNICIPIO DE AGUAI/SP'
#  'HOSPITAL MUNICIPAL DE BERTIOGA'
#  'C.R.E.I. CENTRO DE REFERENCIA EM EMERGEN'
#  'HOSPITAL MUNICIPAL SAO LUIZ GONZAGA'
#  'HOSPITAL MUNICIPAL DR.  GUIDO GUIDA' 'HOSPITAL SANTA CASA'
#  'SANTA CASA DESTA CIDADE DE PATROCINIO PA' 'NA RUA JOAO LEITE DE GODOI'
#  'SAO GERALDO' 'NA RUA AGUA VERMELHA' 'ESTADUAL  DE  MIRANDOPOLIS'
#  'CASA DE REPOUSO SANTA BARBARA' 'NA RUA DR.MELLO N�443' 'UPA CENTRO'
#  'HOSPITAL SANTO ANTONIO' 'SEU  NA RUA PADRE NOBREGA' 'CASA'
#  'SEU  NA RUA CEARA' 'HOSPITAL MUNICIPAL DR. IGNACIO PROENCA D' '(EM )'
#  'OUTROS' 'CASA CORA CORALINA' 'NA RODOVIA COMANDANTE JOAO RIBEIRO DE BA'
#  'CASA DE REPOUSO EVA ALVES' 'HOSPITAL ESTADUAL BAURU' 'HOSPITAL FAMILY'
#  'SEU  NA RUA PARA' 'ESTADUAL MARIO COVAS'
#  'SEU  NA RUA SAO VICENTE DE PAULA' 'HOSPITAL SAO MARCOS'
#  'HOSPITAL E MATERNIDADE SAO LUCAS' 'NA RUA AVARE'
#  'HOSPITAL E MATERNIDADE "ASSOCIACAO FILHA' 'HOSPITAL SAO PAULO'
#  'SANTA CASA DE MISERICORDIA DE PATROCINIO'
#  'ASSOCIACAO FILHAS DE SAO CAMILO'
#  'ASSOCIACAO SUICA DE BENEFICENCIA HELVETI' 'JOSERF ALBERT LOUIS DEGRYSE'
#  'HOSPITAL DAS CLINICAS LUZIA DE PINHO MEL'
#  'HOSPITAL DAS CLINICAS DA FMUSP' 'NA RUA VEREADOR ETTORE VELARDI'
#  'E MATERNIDADE REGIONAL' 'IRMANDADE SANTA CASA DE MISERICORDIA'
#  'ORGANIZACAO SOCIAL DE SAUDE  SANTA MARCE' 'HOSPITAL MEDICAL'
#  'HOSPITAL SAO FRANCISCO LOCAL' 'PA SANTA TEREZA' 'HOSPITAL DE PERUS'
#  'UNIDADE BASICA DE SAUDE' 'HOSPITAL IRMANDADE SANTA CASA DE MISERIC'
#  'HOSPITAL DO SEPACO' 'IRMANDADE SANTA CASA DE MISERICORDIA SAO'
#  'HOSPITAL E MATERNIDADE SAO SEBASTIAO' 'SANTA CASA'
#  'HOSPITAL SANTO ANTONIO - APAMIR' 'CENTRO DE SAUDE' 'RODOVIA 165' 'UPA'
#  'HOSPITAL' 'CASA DE REPOUSO POUSADA DO SOL' 'CENTRO DE SAUDE III'
#  'NA RUA HUM' 'SANTA LUZIA' 'NO SITIO VITI FRUT' 'NA RUA UM'
#  'NA RUA ENIO GIOVANETTI' 'VIA PUBLICA' 'SEU  NA RUA SANTOS DUMONT'
#  'CASA DE SAUDE STELLA MARIS' 'A RUA CAMPOS SALLES'
#  'HOSPITAL REGIONAL DE ITAPETININGA/SP'
#  'HOSPITAL MUNICIPAL ANTONIO GIGLIO'
#  'SANTA CASA DE MISERICORDIA DE APARECIDA-' 'HOSPITAL CIDADE TIRADENTES'
#  'NA RUA PRUDENTE DE MORAES' 'A RUA FLAVIO TORELLI'
#  'HOSPITAL MUNICIPAL PROFESSOR WALDOMIRO D' 'NO SITIO TAQUARAL'
#  'SEU  NA RUA JOAO CAVALARI' 'FLORIANO PEIXOTO' 'IRMANDADE SANTA CASA'
#  'DR FRANCISCO RIBEIRO ARANTES' 'MUNICIPAL LEONARDUS VAN MELIS'
#  'HOSPITAL SANTA MARCELINA' 'DAS BANDEIRAS' 'HOSPITAL UNIMED'
#  'HOSPITAL REGIONAL SUL' 'MUNICIPAL' 'NESTE MUNICIPIO'
#  'MUNICIPAL REYNALDO GUERRA' 'HOSPITAL MAJOR ANTONIO CANDIDO - BATATAI'
#  'SANTA CASA LOCAL' 'HOSPITAL NOSSA SENHORA DA PIEDADE'
#  'SANTA CASA DE P VENCESLAU' 'JULIA RUETE' 'PRONTO ANTEDIMENTO BANGU'
#  'DO ARPUI' 'DOLICILIO NA RUA AGONFO ROGERIO N  330' 'NA RUA DO BOSQUE'
#  'HOSPITAL DAS CLINICAS' 'INSTITUTO DO CANCER DO ESTADO DE SAO PAU'
#  'UNIDADE BASICA DE SAUDE I' 'HOSPITAL DA SANTA CASA DESTA CIDADE'
#  'COMPLEXO HOSPITALAR PREFEITO EDIVALDO OR'
#  'HOSPITAL SANTA CASA DE MISERICORDIA'
#  'HOSPITAL MUNICIPAL DE NAZARE PAULISTA' 'PRONTO SOCORRO MUNICIPAL'
#  'UNIDADE DE PRONTO ATENDIMENTO (UPA) JORD'
#  'CASA DE REPOUSO CANTINHO DO SOSSEGO' 'UBS (UNIDADE BASICA DE SAUDE)'
#  'UNIDADE BASICA DE SAUDE INTEGRADA'
#  'PENSIONATO HOUSE CARE RIO PRETO LTDA - M' 'CENTRO DE SAUDE DE CANITAR'
#  'HOSPITAL MUNICIPAL DE IEPE' 'PRONTO SOCORRO DE SETE BARRAS'
#  'P ARTUR COSTA SILVA' 'HOSPITAL REGIONAL DE ITANHAEM'
#  'SAO LUCAS DE SANTOS' 'HOSPITAL RIBEIRAO PIRES'
#  'CASA DE REPOUSO PEDACINHO DO CEU' 'CASA DE REPOUSO ACONCHEGO'
#  'CASA DE REPOUSO VALE DOS LIRIOS' 'IRMANDADE DA SANTA CASA DE VINHEDO'
#  'CONJUNTO HOSPITALAR DO MANDAQUI -' 'HOSPITAL MUNICIPAL DE JANDIRA'
#  'HOSPITAL IRMANDADE DA SANTA CASA DE MISE' 'NA RUA SANTO ANTONIO'
#  'NO SITIO AGUA DA SAUDADE' 'E MATERNIDADE DE RANCHARIA'
#  'HOSPITAL DE MISERICORDIA NOSSA SENHORA A' 'HOSPITAL MUNICIPAL'
#  'UPA SAO FRANCISCO XAVIER' '(EM ) SITO A RUA OSWALDO COLLINO'
#  'ASSOCIACAO BENEFICENTE DE BILAC' 'UBS CENTRAL DE RIO GRANDE DA SERRA'
#  'INSTITUTO LAURO DE SOUZA LIMA'
#  'HOSPITAL REGIONAL DR. LEOPOLDO BEVILACQU' 'RESIDENCIA'
#  'HOSPITAL SANTO ANTONIO  DE JUQUIA - SP'
#  'IRMANDADE SANTA CASA DE IPAUSSU' 'SANTA CASA- LOCAL'
#  'HOSPITAL SAO JORGE' 'CASA DE SAUDE DE PONTES GESTAL'
#  'FUNDACAO ESPIRITA ALLAN KARDEC'
#  'NA AVENIDA GOIAS, N. 2820, APTO 84, BAIR'
#  'CASA DE CARIDADE SAO VICENTE DE PAULO'
#  'SOCIEDADE BENEFICENTE HOSPITALAR SANTA R'
#  'HOSPITAL GERAL DE ITAPECERICA DA SERRA'
#  'UNIDADE MISTA DE SAUDE DE JUQUITIBA' 'UNIDADE MISTA DE SAUDE'
#  'HOSPITAL E MATERNIDADE "MADRE VANNINI"'
#  'INSTITUTO DE ORTOPEDIA DA FMUSP' 'PRONTO SOCORRO MUNICIPAL DE PERUS'
#  'NA RUA ARACAJU,  99, BAIRRO MARIA GENOVE'
#  'HOSPITAL METROPOLITANO - UNIDADE AVANCAD'
#  'HOSPITAL DA SANTA CASA DE SERRANA/SP'
#  'UNIMED DE VOTUPORANGA COOPERATIVA DE TRA'
#  'HOSPITAL E MATERNIDADE DE CORDEIROPOLIS' 'LAR DOS IDOSOS JU MASCIA'
#  'COMPLEXO HOSPITALAR GRANJA VIANA' 'HOSPITAL SANCTA MAGGIORE'
#  'CENTRO HOSPITALAR PENITENCIARIO' 'HOSPITAL REGIONAL DE COTIA'
#  'UPA CAMPO LIMPO' 'EM SEU DOMICILIO, NESTE DISTRITO, NA AVE'
#  'ASSOCIACAO BENEFICENTE MORADA DO IDOSO' 'REGIONAL CONDERG'
#  'IRMANDADE SANTA CASA DE MISERICORDIA DE'
#  'HOSPITAL REGIONAL DO VALE DO PARAIBA EM' 'HOSPITAL ITAMARATY'
#  'HOSPITAL DE CLINICAS' 'O PRONTO SOCORRO MUNICIPAL'
#  'SOCIEDADE OPERARIA HUMANITARIA' 'FUNDACAO PIO XII'
#  'FUNDACAO PIO XII - UNIDADE 1' 'HOSPITAL SENHOR BOM JESUS'
#  'A R.ANTONIO DOMINGOS PELISER' 'HOSPITALLAR NOSSA SENHORA DAS GRACAS NA'
#  'HOSPITAL MAJOR ANTONIO CANDIDO' 'UPA (UNIDADE DE PRONTO ATENDIMENTO)'
#  'HOSPITAL DIA DA UNIMED' 'HOSPITAL E MATERNIDADE GALILEO'
#  'HOSPITAL AUGUSTO DE OLIVEIRA CAMARGO' 'IGREJA' 'P.A'
#  'PRONTO ATENDIMENTO VILA LUZITA' 'SANTA HELENA'
#  'HOSPITAL MUNICIPAL DO TATUAPE DR. CARMIN' 'HOSPITAL SIRIO LIBANES'
#  'PS VILA IOLANDA' 'HOSPITAL ESTADUAL VILA ALPINA'
#  'HOSPITAL ANTONIO CANDIDO CAMARGO'
#  'HOSPITAL MUNICIPAL DE EMERGENCIAS ALBERT' 'RECANTO SAO CAMILO - JACANA'
#  'P.S. MUNICIPAL DR. LAURO RIBAS BRAGA -'
#  'HOSPITAL MUNICIPAL VEREADOR JOSE STOROPO' 'CORTEGACA'
#  'HOSPITAL GERAL ALVARO SIMOES DE SOUZA' 'HOSPITAL GERAL DE PEDREIRA'
#  'HOSPITAL DO MANDAQUI -' 'HOSPITAL DO SERVIDOR PUBLICO MUNICIPAL'
#  'NA RUA VINTE E QUATRO' 'HOSPITAL BENEFICENCIA PORTUGUESA'
#  'HOSPITAL MUNICIPAL PROF. DR. ALIPIO CORR'
#  'NA RUA MANOEL AUGUSTO FERREIRINHA  83- B' 'HOSPITAL PAULISTANO'
#  'HOSPITAL GERAL DE VILA NOVA CACHOEIRINHA' 'HOSPITAL SANTA CECILIA'
#  'HOSPITAL FRANCISCO MORATO DE OLIVEIRA'
#  'INSTITUTO DO CANCER DE SAO PAULO'
#  'INSTITUTO DE INFECTOLOGIA DO HOSPITAL EM'
#  'HOSPITAL E MATERNIDADE SAO CRISTOVAO'
#  'INSTITUTO DO CANCER DR. ARNALDO VIEIRA D' 'IGESP S/A C.M.C.'
#  'HOSPITAL ISRAELITA ALBERT EINSTEIN' 'HOSPITAL E MATERNIDADE BARTIRA'
#  'HOSPITAL SAO JUDAS TADEU - FUNDACAO PIO' 'HOSPITAL REGIONAL'
#  'SANTA CASA DE IPAUSSU' 'SOCIEDADE SANTA CASA'
#  '(EM ) SITO A RUA JOSE AURELIANO DA CUNHA' '(EM ) SITO A RUA ROSA COTINE'
#  'HOSPITAL REGIONAL DOUTOR VIVALDO MARTINS' 'HOSPITAL DE CLINICAS SUL'
#  'SANTOS DUMONT HOSPITAL' 'HOSPITAL E MATERNIDADE SAO JOSE'
#  'HOSPITAL TEREZA PERLATTI' 'HOSPITAL UNIMED BAURU'
#  'SANTA CASA DE MISERICORDIA DE CERQUEIRA'
#  'MUNICIPAL LEONARDUS VAN MELIS\t\t\t' 'SANTA TEREZINHA'
#  'A RUA MAESTRO VICTORIO BARBIN' 'A RUA CEL. MANOEL DE SOUZA MEIRELLES'
#  'PRONTO SOCORRO DE TAMBAU' 'A RUA RIVADAVIA FERREIRA DE CARVALHO'
#  'UPA JARDIM MARINGA -AV. BARAO DE MAUA'
#  'UPA VILA MAGINI - AV. WASHINGTON LUIZ' 'CENTRO HOSPITALAR SANTO ANDRE'
#  'HOSPITAL NOSSA SENHORA DE FATIMA'
#  'REDE D�OR SAO LUIZ S.A. - UNIDADE BRASIL'
#  'HOSPITAL SANTA MARCELINA DO ITAIM PAULIS'
#  'IRMANDADE DA SANTA CASA DE LOUVEIRA' 'HOSPITAL SAO FRANCISCO'
#  'CASA DE REPOUSO DAY CARE' 'HOSPITAL BOM SAMARITANO' 'UPA DA ENSEADA'
#  'UPA DA RODOVIARIA' 'SEU  NA RUA DALVA DUARTE MARQUES'
#  'SANTA CASA DE FRANCA-SP' 'SANTA CASA DE PATROCINIO PAULISTA-SP'
#  'PRONTO SOCORRO AGENOR DE CAMPOS' 'PRONTO SOCORRO CENTRAL'
#  'HOSPITAL E MATERNIDADE SINO BRASILEIRO' 'MUNICIPAL DE SANTO ANDRE'
#  'MATERNIDADE BENEFICENCIA PORTUGUESA DE S'
#  'E MATERNIDADE DR. CHRISTOVAO DA GAMA' 'PRONTO ATENDIMENTO BANGU'
#  'NA RUA JOSE OLANDA  29- BAIRRO BOA VISTA' 'UPA 24 HRS'
#  'OUTRO ESTABELECIMENTO DE SAUDE.'
#  'EM DOMICILIO A RUA PEDRO ROSA,N  19,FUND'
#  'SANTA CASA DE MISERICORDIA DE GUARATINGU' 'NA AVENIDA SANTA RITA' 'CEAM'
#  'HOSPITAL ESTADUAL DE SUMARE' 'HOSPITAL DA SANTA CASA'
#  'HOSPITAL D. CAROLINA DE FIGUEIREDO' 'HOSPITAL VITAL'
#  'UBS JARDIM SONIA MARIA - RUA CARMEM MIRA' 'UPA JARDIM SANTO ANDRE'
#  'IRMANDADE DA SANTA CASA' 'ASSOCIACAO HOSPITALAR SANTA CASA DE LINS'
#  'EM DOMICILIO, NA AVENIDA DA SAUDADE, N�'
#  'UNIDADE DE ATENDIMENTO DE URGENCIA E EME'
#  'SANTA CASA DE GUARATINGUETA-SP'
#  'EM DOMICILIO A RUA ANTENOR DE VASCONCELO'
#  'HOSPITAL E MATERNIDADE FREI GALVAO'
#  'EM DOMICILIO A RUA CRISTAL, N� 86 - JARD'
#  'EM DOMICILIO A RUA SIQUEIRA CAMPOS,N  73'
#  'EM DOMICILIO A RUA BERILO, N� 21, JARDIM'
#  'NA RUA CURITIBA N� 226 - VISTA ALEGRE, D'
#  'NA RUA ANGELO LUCCHESI N� 117 - PARQUE S'
#  'HOSPITAL E MATERNIDADE FREI GALVAO - DES'
#  'PREDIO DA SANTA CASA DE MISERICORDIA'
#  'PREDIO DA SANTA CASA DE MISERICORDIA SI' 'P.S. ANISIO ROSAN'
#  'SANTA CASA DA MISERICORDIA' 'HOSPITAL MUNICIPAL DR. MARIO GATTI'
#  'HOSPITAL SANTA BARBARA' 'HOSPITAL MUNICIPAL DR. ARTHUR DOMINGUES'
#  'NA RUA SANTA CRUZ' 'UNIDADE MISTA DE SAUDE DE ARACOIABA DA S'
#  'UNIDADE MISTA DE ARACOIABA DA SERRA'
#  'HOSPITAL METROPOLITANO UNIDADE AVANCADA' 'HOSPITAL DA LUZ'
#  'CASA DE REPOUSO NA RUA MARIO MARCHETTI' 'HOSPITAL GERAL DE TAIPAS'
#  'SANTA CASA DE MISECORDIA DONA CAROLINA M' 'HOSPITAL VERA CRUZ'
#  'PRONTO SOCORRO MUNICIPAL DIADEMA']
# [nan '25255' '132714' ... '199683' '138687' '9722']
# [nan 'S' 'N']
# [nan 'S' 'N']
# [nan '3.2.01' '3.2.00' '3.2.02' '2.2.00' '2.2.03' '2.2.08' '3.2.30'
#  '3.2.50']
# [nan 'T794/X959' 'C509' ... 'I10/I64/R64/R092' 'I461/A09/E87*L97 E14'
#  'I219/I64/I709/B342 U071*I255 E149']
# [nan 'XXXXXS' 'SXSXXX' 'SXXXXX' 'XXSXXX' 'SSXXXX' 'SXSXSS' 'SSSXXX'
#  'XSXXXX' 'XSSSXX' 'XSSXXX' 'XXXSXX' 'SSXXXS' 'SXSXSX' 'XXSSXX' 'XXXXSS'
#  'SSSSXS' 'SXXXXS' 'SXSXXS' 'SXSSXX' 'XXXXSX' 'XXSXSX' 'XXSXXS' 'SXXXSX'
#  'SSSXXS' 'XSXXXS' 'XSSXXS' 'XXSSXS' 'XSXXSX' 'SSSXSS' 'SSSXSX' 'XSXSXX'
#  'SXXXSS' 'SSXSXX' 'SXXSXX' 'XXXSSX' 'XSXXSS' 'SSXXSS' 'SSXSXS' 'SSXXSX'
#  'SXXSXS' 'XXXSXS' 'SSSSXX' 'XXSXSS' 'XSSXSX' 'SSSSSS' 'XSXSXS' 'XSSXSS'
#  'XSSSXS' 'XXSSSX' 'SXSSXS' 'XXXXXX' 'SXXSSX' 'SXSSSX' 'SSSSSX' 'XSSSSX'
#  'SSXSSX' 'XSXSSX' 'XXXSSS' 'XSXSSS' 'SSXSSS']
# [nan 'M' 'R' 'E']
# [nan 'XXXXXXX' 'XXXSXXX' 'XXSXXXX' 'XSXXXSX' 'SXXXXXX' 'SXSXXXX' 'XXSSXXX'
#  'SXSSXXX' 'SSSXXXX' 'XXXXSXX' 'SXXSXXX' 'SSSSXXX' 'XXSSXSX' 'SXSSXSX'
#  'SXSSSXX' 'XXSSSXX' 'XXXXXXS' 'SSSSSXX' 'SSSXSXX' 'SSXSXXX' 'SXSXSXX'
#  'SSSXXXS' 'SXSXXSX' 'XSSXXXX' 'XXSXSXX' 'XSSSSXX' 'XSSSXXX' 'SXXSXXS'
#  'XSXSXXX' 'XXXXSXS' 'SSXXXXX' 'SXXSSXX' 'XSXXXXX' 'SXXSXSS' 'XXSXXSX'
#  'SSXXSXX' 'SSSSXSX' 'XXXSSXX' 'SSSXXSX' 'SXSSXXS' 'XSXSSXX' 'SSSSXXS'
#  'SSXXXSX' 'SXXXSXX' 'SSXSXSX' 'SXXXXXS' 'XXXSXXS' 'XSSSXSX' 'SSXSSXX'
#  'XXXSXSX' 'XXSXSSX' 'XSXXSXX' 'SXXSXSX' 'XSXSSSX' 'XXXXXSX' 'XXSSXXS'
#  'SXXXXSX' 'XSSXSXX' 'XXSXXXS' 'XSXSXSX' 'SXSXXXS']

# %%
df = df.dropna(subset=['coluna_com_muitas_nans'])
df['coluna_com_erros'] = df['coluna_com_erros'].replace('valor_invalido', np.nan)
df = df.fillna(method='ffill')
df = df.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-1a8dc3092a22> in <module>
# ----> 1 df = df.dropna(subset=['coluna_com_muitas_nans'])
#       2 df['coluna_com_erros'] = df['coluna_com_erros'].replace('valor_invalido', np.nan)
#       3 df = df.fillna(method='ffill')
#       4 df = df.drop_duplicates()
#
# ~\anaconda3\envs\envpowerbi\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5002             check = indices == -1
#    5003             if check.any():
# -> 5004                 raise KeyError(list(np.compress(check, subset)))
#    5005             agg_obj = self.take(indices, axis=agg_axis)
#    5006
#
# KeyError: ['coluna_com_muitas_nans']

# %%
import pandas as pd

# Listar as colunas que contêm a palavra "IDADE"
colunas_idade = data.filter(like='IDADE').columns

# Imprimir os nomes das colunas que contêm a palavra "IDADE"
print(colunas_idade)
# Out:
# Index(['IDADEMAE', 'IDADEminutos', 'IDADEhoras', 'IDADEdias', 'IDADEmeses',
#        'IDADEanos'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Criando um histograma para a variável 'IDADE'
plt.hist(df['IDADEanos'])
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.show()

# Criando um boxplot para comparar a variável 'IDADE' entre os sexos
sns.boxplot(x='SEXO', y='IDADEanos', data=df)
plt.show()

# Criando um scatter plot para visualizar a relação entre 'IDADE' e 'QTDFILVIVO'
sns.scatterplot(x='IDADEanos', y='QTDFILVIVO', data=df)
plt.show()
